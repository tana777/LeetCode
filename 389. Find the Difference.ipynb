# %% [markdown]
# ##### 389. Find the Difference
#
# Given two strings s and t which consist of only lowercase letters. <br>
# String t is generated by random shuffling string s and then add one more letter at a random position. <br>
#
# Find the letter that was added in t. <br>
#
# Example: <br>
# Input: <br>
# s = "abcd" <br>
# t = "abcde" <br>
#
# Output: <br>
# e <br>
#
# Explanation: <br>
# 'e' is the letter that was added. <br>

# %%
class Solution:
    def findTheDifference(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: str
        """
        s = sorted(s)
        t = sorted(t)
        for i in range(len(s)):
            if t[i] != s[i]:
                return t[i]
        return t[-1]

# %%
class Solution:
    def findTheDifference(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: str
        """
        import collections
        st = collections.Counter(s)
        tt = collections.Counter(t)
        for letter, ct in tt.items():
            if st[letter] ==0:
                return letter  
            elif st[letter] < ct:
                return letter
   
    
## hash table

# %%
def findTheDifference(self, s, t):
    """
    :type s: str
    :type t: str
    :rtype: str
    """
    ans = 0
    for c in s + t:
        ans ^= ord(c)
    return chr(ans)

## Bit manipulation

# %%
s = 'abcd'
t = 'abcde'
S = Solution()
S.findTheDifference(s,t)
# Out:
# 'e'
